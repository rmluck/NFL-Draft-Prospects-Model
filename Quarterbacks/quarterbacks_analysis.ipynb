# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import norm
import seaborn as sns
from matplotlib.offsetbox import OffsetImage, AnnotationBbox
import os
from adjustText import adjust_text

# %%
qbs = pd.read_csv("quarterbacks.csv")
qbs = qbs.drop(columns=["NFL Stats", "College Stats", "Position"])
qbs.loc[qbs["Arm"] == "Right", "Arm"] = 1
qbs.loc[qbs["Arm"] == "Left", "Arm"] = 0

mean = qbs["Arm Length"].mean()
stdev = qbs["Arm Length"].std()
qbs["Arm Length"] = qbs["Arm Length"].apply(lambda x: norm.cdf(x, loc=mean, scale=stdev) * 100)

mean = qbs["Hand Size"].mean()
stdev = qbs["Hand Size"].std()
qbs["Hand Size"] = qbs["Hand Size"].apply(lambda x: norm.cdf(x, loc=mean, scale=stdev) * 100)

mean = qbs["Wingspan"].mean()
stdev = qbs["Wingspan"].std()
qbs["Wingspan"] = qbs["Wingspan"].apply(lambda x: norm.cdf(x, loc=mean, scale=stdev) * 100)

mean = qbs["40-Yard Dash"].mean()
stdev = qbs["40-Yard Dash"].std()
qbs["40-Yard Dash"] = qbs["40-Yard Dash"].apply(lambda x: 100 - (norm.cdf(x, loc=mean, scale=stdev) * 100))

mean = qbs["20-Yard Dash"].mean()
stdev = qbs["20-Yard Dash"].std()
qbs["20-Yard Dash"] = qbs["20-Yard Dash"].apply(lambda x: 100 - (norm.cdf(x, loc=mean, scale=stdev) * 100))

mean = qbs["10-Yard Dash"].mean()
stdev = qbs["10-Yard Dash"].std()
qbs["10-Yard Dash"] = qbs["10-Yard Dash"].apply(lambda x: 100 - (norm.cdf(x, loc=mean, scale=stdev) * 100))

mean = qbs["Speed Score"].mean()
stdev = qbs["Speed Score"].std()
qbs["Speed Score"] = qbs["Speed Score"].apply(lambda x: norm.cdf(x, loc=mean, scale=stdev) * 100)

mean = qbs["Bench"].mean()
stdev = qbs["Bench"].std()
qbs["Bench"] = qbs["Bench"].apply(lambda x: norm.cdf(x, loc=mean, scale=stdev) * 100)

mean = qbs["Shuttle"].mean()
stdev = qbs["Shuttle"].std()
qbs["Shuttle"] = qbs["Shuttle"].apply(lambda x: 100 - (norm.cdf(x, loc=mean, scale=stdev) * 100))

mean = qbs["3-Cone"].mean()
stdev = qbs["3-Cone"].std()
qbs["3-Cone"] = qbs["3-Cone"].apply(lambda x: 100 - (norm.cdf(x, loc=mean, scale=stdev) * 100))

mean = qbs["Agility Score"].mean()
stdev = qbs["Agility Score"].std()
qbs["Agility Score"] = qbs["Agility Score"].apply(lambda x: norm.cdf(x, loc=mean, scale=stdev) * 100)

mean = qbs["Broad Jump"].mean()
stdev = qbs["Broad Jump"].std()
qbs["Broad Jump"] = qbs["Broad Jump"].apply(lambda x: norm.cdf(x, loc=mean, scale=stdev) * 100)

mean = qbs["Vertical Jump"].mean()
stdev = qbs["Vertical Jump"].std()
qbs["Vertical Jump"] = qbs["Vertical Jump"].apply(lambda x: norm.cdf(x, loc=mean, scale=stdev) * 100)

mean = qbs["Burst Score"].mean()
stdev = qbs["Burst Score"].std()
qbs["Burst Score"] = qbs["Burst Score"].apply(lambda x: norm.cdf(x, loc=mean, scale=stdev) * 100)

mean = qbs["Athlete Score"].mean()
stdev = qbs["Athlete Score"].std()
qbs["Athlete Score"] = qbs["Athlete Score"].apply(lambda x: norm.cdf(x, loc=mean, scale=stdev) * 100)

mean = qbs["BMI"].mean()
stdev = qbs["BMI"].std()
qbs["BMI"] = qbs["BMI"].apply(lambda x: norm.cdf(x, loc=mean, scale=stdev) * 100)

# mean = qbs["Completions"].mean()
# stdev = qbs["Completions"].std()
# qbs["Completions"] = qbs["Completions"].apply(lambda x: norm.cdf(x, loc=mean, scale=stdev) * 100)

# mean = qbs["Pass Attempts"].mean()
# stdev = qbs["Pass Attempts"].std()
# qbs["Pass Attempts"] = qbs["Pass Attempts"].apply(lambda x: norm.cdf(x, loc=mean, scale=stdev) * 100)

# mean = qbs["Completion Percentage"].mean()
# stdev = qbs["Completion Percentage"].std()
# qbs["Completion Percentage"] = qbs["Completion Percentage"].apply(lambda x: norm.cdf(x, loc=mean, scale=stdev) * 100)

# mean = qbs["Adjusted Completion Percentage"].mean()
# stdev = qbs["Adjusted Completion Percentage"].std()
# qbs["Adjusted Completion Percentage"] = qbs["Adjusted Completion Percentage"].apply(lambda x: norm.cdf(x, loc=mean, scale=stdev) * 100)

# mean = qbs["Big-Time Pass Percentage"].mean()
# stdev = qbs["Big-Time Pass Percentage"].std()
# qbs["Big-Time Pass Percentage"] = qbs["Big-Time Pass Percentage"].apply(lambda x: norm.cdf(x, loc=mean, scale=stdev) * 100)

# mean = qbs["Turnover-Worthy Pass Percentage"].mean()
# stdev = qbs["Turnover-Worthy Pass Percentage"].std()
# qbs["Turnover-Worthy Pass Percentage"] = qbs["Turnover-Worthy Pass Percentage"].apply(lambda x: norm.cdf(x, loc=mean, scale=stdev) * 100)

# mean = qbs["Dropped Pass Percentage"].mean()
# stdev = qbs["Dropped Pass Percentage"].std()
# qbs["Dropped Pass Percentage"] = qbs["Dropped Pass Percentage"].apply(lambda x: norm.cdf(x, loc=mean, scale=stdev) * 100)

# mean = qbs["Pressure Rate"].mean()
# stdev = qbs["Pressure Rate"].std()
# qbs["Pessure Rate"] = qbs["Pressure Rate"].apply(lambda x: norm.cdf(x, loc=mean, scale=stdev) * 100)

# mean = qbs["Pressure to Sack Percentage"].mean()
# stdev = qbs["Pressure to Sack Percentage"].std()
# qbs["Pressure to Sack Percentage"] = qbs["Pressure to Sack Percentage"].apply(lambda x: 100 - (norm.cdf(x, loc=mean, scale=stdev) * 100))

# mean = qbs["Air Yards Pass Percentage"].mean()
# stdev = qbs["Air Yards Pass Percentage"].std()
# qbs["Air Yards Pass Percentage"] = qbs["Air Yards Pass Percentage"].apply(lambda x: norm.cdf(x, loc=mean, scale=stdev) * 100)

# mean = qbs["Average Time to Throw"].mean()
# stdev = qbs["Average Time to Throw"].std()
# qbs["Average Time to Throw"] = qbs["Average Time to Throw"].apply(lambda x: 100 - (norm.cdf(x, loc=mean, scale=stdev) * 100))

# mean = qbs["Pass Yards"].mean()
# stdev = qbs["Pass Yards"].std()
# qbs["Pass Yards"] = qbs["Pass Yards"].apply(lambda x: norm.cdf(x, loc=mean, scale=stdev) * 100)

# mean = qbs["Pass Yards per Attempt"].mean()
# stdev = qbs["Pass Yards per Attempt"].std()
# qbs["Pass Yards per Attempt"] = qbs["Pass Yards per Attempt"].apply(lambda x: norm.cdf(x, loc=mean, scale=stdev) * 100)

# mean = qbs["Average Depth of Target"].mean()
# stdev = qbs["Average Depth of Target"].std()
# qbs["Average Depth of Target"] = qbs["Average Depth of Target"].apply(lambda x: norm.cdf(x, loc=mean, scale=stdev) * 100)

# mean = qbs["Deep Yards"].mean()
# stdev = qbs["Deep Yards"].std()
# qbs["Deep Yards"] = qbs["Deep Yards"].apply(lambda x: norm.cdf(x, loc=mean, scale=stdev) * 100)

# mean = qbs["Screen Yards"].mean()
# stdev = qbs["Screen Yards"].std()
# qbs["Screen Yards"] = qbs["Screen Yards"].apply(lambda x: norm.cdf(x, loc=mean, scale=stdev) * 100)

# mean = qbs["Pass Touchdowns"].mean()
# stdev = qbs["Pass Touchdowns"].std()
# qbs["Pass Touchdowns"] = qbs["Pass Touchdowns"].apply(lambda x: norm.cdf(x, loc=mean, scale=stdev) * 100)

# mean = qbs["Interceptions"].mean()
# stdev = qbs["Interceptions"].std()
# qbs["Interceptions"] = qbs["Interceptions"].apply(lambda x: 100 - (norm.cdf(x, loc=mean, scale=stdev) * 100))

# mean = qbs["Passer Rating"].mean()
# stdev = qbs["Passer Rating"].std()
# qbs["Passer Rating"] = qbs["Passer Rating"].apply(lambda x: norm.cdf(x, loc=mean, scale=stdev) * 100)

# mean = qbs["Rush Attempts"].mean()
# stdev = qbs["Rush Attempts"].std()
# qbs["Rush Attempts"] = qbs["Rush Attempts"].apply(lambda x: norm.cdf(x, loc=mean, scale=stdev) * 100)

# mean = qbs["Rush Yards"].mean()
# stdev = qbs["Rush Yards"].std()
# qbs["Rush Yards"] = qbs["Rush Yards"].apply(lambda x: norm.cdf(x, loc=mean, scale=stdev) * 100)

# mean = qbs["Rush Yards per Attempt"].mean()
# stdev = qbs["Rush Yards per Attempt"].std()
# qbs["Rush Yards per Attempt"] = qbs["Rush Yards per Attempt"].apply(lambda x: norm.cdf(x, loc=mean, scale=stdev) * 100)

# mean = qbs["Rush Touchdowns"].mean()
# stdev = qbs["Rush Touchdowns"].std()
# qbs["Rush Touchdowns"] = qbs["Rush Touchdowns"].apply(lambda x: norm.cdf(x, loc=mean, scale=stdev) * 100)

# mean = qbs["Passing Grade"].mean()
# stdev = qbs["Passing Grade"].std()
# qbs["Passing Grade"] = qbs["Passing Grade"].apply(lambda x: norm.cdf(x, loc=mean, scale=stdev) * 100)

# mean = qbs["Intermediate Passing Grade"].mean()
# stdev = qbs["Intermediate Passing Grade"].std()
# qbs["Intermediate Passing Grade"] = qbs["Intermediate Passing Grade"].apply(lambda x: norm.cdf(x, loc=mean, scale=stdev) * 100)

# mean = qbs["Deep Passing Grade"].mean()
# stdev = qbs["Deep Passing Grade"].std()
# qbs["Deep Passing Grade"] = qbs["Deep Passing Grade"].apply(lambda x: norm.cdf(x, loc=mean, scale=stdev) * 100)

# mean = qbs["No Pressure Passing Grade"].mean()
# stdev = qbs["No Pressure Passing Grade"].std()
# qbs["No Pressure Passing Grade"] = qbs["No Pressure Passing Grade"].apply(lambda x: norm.cdf(x, loc=mean, scale=stdev) * 100)

# mean = qbs["Pressure Passing Grade"].mean()
# stdev = qbs["Pressure Passing Grade"].std()
# qbs["Pressure Passing Grade"] = qbs["Pressure Passing Grade"].apply(lambda x: norm.cdf(x, loc=mean, scale=stdev) * 100)

# mean = qbs["Release Speed"].mean()
# stdev = qbs["Release Speed"].std()
# qbs["Release Speed"] = qbs["Release Speed"].apply(lambda x: norm.cdf(x, loc=mean, scale=stdev) * 100)

# mean = qbs["Short Passing"].mean()
# stdev = qbs["Short Passing"].std()
# qbs["Short Passing"] = qbs["Short Passing"].apply(lambda x: norm.cdf(x, loc=mean, scale=stdev) * 100)

# mean = qbs["Medium Passing"].mean()
# stdev = qbs["Medium Passing"].std()
# qbs["Medium Passing"] = qbs["Medium Passing"].apply(lambda x: norm.cdf(x, loc=mean, scale=stdev) * 100)

# mean = qbs["Long Passing"].mean()
# stdev = qbs["Long Passing"].std()
# qbs["Long Passing"] = qbs["Long Passing"].apply(lambda x: norm.cdf(x, loc=mean, scale=stdev) * 100)

# mean = qbs["Rush/Scramble"].mean()
# stdev = qbs["Rush/Scramble"].std()
# qbs["Rush/Scramble"] = qbs["Rush/Scramble"].apply(lambda x: norm.cdf(x, loc=mean, scale=stdev) * 100)

# mean = qbs["PFF Grade"].mean()
# stdev = qbs["PFF Grade"].std()
# qbs["PFF Grade"] = qbs["PFF Grade"].apply(lambda x: norm.cdf(x, loc=mean, scale=stdev) * 100)

# %%
color_mapping = {
    5: "darkgreen",
    4: "green",
    3: "lightgreen",
    2: "yellow",
    1: "gray",
    0: "lightgray"
}

plt.figure(figsize=(8, 6))
for rating, color in color_mapping.items():
    subset = qbs[qbs["PROSPECT RATING"] == rating]
    plt.scatter(subset["Height"], subset["Hand Size"], color=color, label=f"Prospect Rating {rating}")

plt.xlabel("Height")
plt.ylabel("Hand Size")
plt.title("QBs")
plt.grid(True)
plt.show()

# %%
def load_image(image_path):
    img = plt.imread(image_path)

    return OffsetImage(img, zoom=0.20)

qbs = pd.read_csv("quarterbacks.csv")
qbs = qbs[qbs["Draft Class"].isin([2023, 2022, 2021, 2020, 2019])]
qbs["scramble_rate"] = qbs["scrambles_x"] / qbs["dropbacks_x"]

plt.figure(figsize=(24, 12))
ax = sns.scatterplot(data=qbs, x="scramble_rate", y="pressure_to_sack_rate", s=0)

annotations = []
for i in range(len(qbs)):
    annotations.append(ax.text(qbs["scramble_rate"][i] + 0.002, qbs["pressure_to_sack_rate"][i], qbs["Player"][i], fontsize=15))
    imagebox = load_image(os.path.abspath(os.path.join(os.getcwd(), os.pardir)) + "/Logos/" + qbs["College"][i] + ".png")
    ab = AnnotationBbox(imagebox, (qbs["scramble_rate"][i], qbs["pressure_to_sack_rate"][i]), frameon=False)
    ax.add_artist(ab)

adjust_text(annotations)
plt.gca().invert_xaxis()
plt.gca().invert_yaxis()
# 27  http://www.sports-reference.com/cfb/players/ma...       QB  Right   23
# 28  http://www.sports-reference.com/cfb/players/ky...       QB  Right   23
# 29  http://www.sports-reference.com/cfb/players/ke...       QB  Right   22
# 30  http://www.sports-reference.com/cfb/players/da...       QB  Right   22
# 31  http://www.sports-reference.com/cfb/players/ia...       QB  Right   23
# 32  http://www.sports-reference.com/cfb/players/sa...       QB  Right   22
# 33  http://www.sports-reference.com/cfb/players/jo...       QB  Right   23
# 34  http://www.sports-reference.com/cfb/players/tu...       QB   Left   22
# 35  http://www.sports-reference.com/cfb/players/ju...       QB  Right   22
# 36  http://www.sports-reference.com/cfb/players/jo...       QB  Right   21
# 37  http://www.sports-reference.com/cfb/players/ja...       QB  Right   22
# 38  http://www.sports-reference.com/cfb/players/ja...       QB  Right   22
# 39  http://www.sports-reference.com/cfb/players/ja...       QB  Right   23
# 40  http://www.sports-reference.com/cfb/players/ja...       QB  Right   22
# 41  http://www.sports-reference.com/cfb/players/ja...       QB  Right   24
# 42  http://www.sports-reference.com/cfb/players/co...       QB  Right   22
# 43  http://www.sports-reference.com/cfb/players/be...       QB  Right   23
# 44  http://www.sports-reference.com/cfb/players/to...       QB  Right   23
# 45  http://www.sports-reference.com/cfb/players/na...       QB  Right   23
# 46  http://www.sports-reference.com/cfb/players/ky...       QB  Right   22
# 47  http://www.sports-reference.com/cfb/players/da...       QB  Right   22
# 48  http://www.sports-reference.com/cfb/players/dw...       QB  Right   22
# 49  http://www.sports-reference.com/cfb/players/dr...       QB  Right   22
# 50  http://www.sports-reference.com/cfb/players/wi...       QB  Right   24
# 51  http://www.sports-reference.com/cfb/players/ry...       QB  Right   24
# 52  http://www.sports-reference.com/cfb/players/ja...       QB  Right   23
# 53                                                NaN       QB  Right   23
# 54  http://www.sports-reference.com/cfb/players/cl...       QB  Right   24
# 55  http://www.sports-reference.com/cfb/players/ga...       QB  Right   23
# 56  http://www.sports-reference.com/cfb/players/tr...       QB  Right   24
#
#     Seasons  Games                College Conference  ...  total_touches  \
# 0         3     36                Alabama        SEC  ...              4
# 1         3     27             Ohio State    Big Ten  ...             24
# 2         3     24                Florida        SEC  ...             65
# 3         4     39               Kentucky        SEC  ...             30
# 4         5     46              Tennessee        SEC  ...             41
# 5         4     32           Fresno State        MWC  ...             15
# 6         4     42                Georgia        SEC  ...             47
# 7         4     33                 Purdue    Big Ten  ...             16
# 8         5     47                Houston   American  ...             55
# 9         5     39                   UCLA     Pac-12  ...             67
# 10        5     51             Penn State    Big Ten  ...             36
# 11        5     31                    BYU        Ind  ...             56
# 12        3     23               Stanford     Pac-12  ...             13
# 13        4     47                    TCU     Big 12  ...             88
# 14        5     52             Pittsburgh        ACC  ...             28
# 15        4     50             Cincinnati   American  ...             78
# 16        4     35                Liberty        Ind  ...             87
# 17        4     37            Mississippi        SEC  ...             75
# 18        1     14       Western Kentucky       CUSA  ...             16
# 19        3     37         North Carolina        ACC  ...             76
# 20        5     41     South Dakota State        MVC  ...             30
# 21        5     45           Kansas State     Big 12  ...             18
# 22        4     48             Iowa State     Big 12  ...             33
# 23        3     35                Clemson        ACC  ...             45
# 24        3     30                    BYU        Ind  ...             52
# 25        3     19     North Dakota State        MVC  ...             13
# 26        3     34             Ohio State    Big Ten  ...             30
# 27        3     31                Alabama        SEC  ...             18
# 28        3     27                Florida        SEC  ...             35
# 29        4     46              Texas A&M        SEC  ...             59
# 30        3     14               Stanford     Pac-12  ...             13
# 31        4     45             Notre Dame        Ind  ...             46
# 32        4     46                  Texas     Big 12  ...             60
# 33        5     38                    LSU        SEC  ...             46
# 34        3     32                Alabama        SEC  ...              4
# 35        4     43                 Oregon     Pac-12  ...             27
# 36        3     38             Utah State        MWC  ...             42
# 37        4     56               Oklahoma     Big 12  ...            164
# 38        3     29             Washington        SEC  ...             24
# 39        5     43  Florida International       CUSA  ...             19
# 40        3     43                Georgia        SEC  ...             25
# 41        4     29           Oregon State     Pac-12  ...             16
# 42        3     33                 Hawaii        MWC  ...             64
# 43        4     41          James Madison   Sun Belt  ...             59
# 44        5     29      Mississippi State        SEC  ...             45
# 45        4     44                   Iowa    Big Ten  ...             48
# 46        3     29               Oklahoma     Big 12  ...             95
# 47        4     36                   Duke        ACC  ...             61
# 48        2     22             Ohio State    Big Ten  ...             46
# 49        4     50               Missouri        SEC  ...             34
# 50        3     28          West Virginia     Big 12  ...             19
# 51        5     46   North Carolina State        ACC  ...             31
# 52        3     37                 Auburn        SEC  ...             30
# 53        5     55     North Dakota State        MVC  ...             95
# 54        4     53           Northwestern    Big Ten  ...             37
# 55        3     30       Washington State     Pac-12  ...             25
# 56        4     46             Penn State    Big Ten  ...            108
#
#    touchdowns_y  yards_y  yards_after_contact  yco_attempt  ypa_y   yprr  \
# 0             4      311                  120         3.53    9.1    NaN
# 1             0      188                   59         1.40    4.5    NaN
# 2             9      713                  345         3.56    7.4   0.00
# 3             2      119                   86         1.91    2.6    NaN
# 4             5      566                  332         4.37    7.4    NaN
# 5             2       55                   46         1.77    2.1    NaN
# 6            10      255                   41         0.69    4.3    NaN
# 7             1       64                   23         0.85    2.4   0.00
# 8             5      697                  317         2.88    6.3    NaN
# 9            12      741                  292         2.58    6.6    NaN
# 10            5      265                   90         1.58    4.6  12.00
# 11            3      403                  165         2.04    5.0  14.00
# 12            2      112                   93         2.51    3.0   0.00
# 13            9      643                  272         2.32    5.5   1.00
# 14            5      440                  234         3.00    5.6   0.00
# 15            6      542                  244         2.54    5.6   8.00
# 16           13     1220                  794         5.26    8.1   6.50
# 17           11      748                  306         2.37    5.8  19.00
# 18            3      140                   45         1.15    3.6  -1.50
# 19           11     1106                  647         4.76    8.1    NaN
# 20            2      300                  124         1.82    4.4   8.00
# 21            4      141                   72         2.32    4.5    NaN
# 22            1      354                  179         2.59    5.1   0.00
# 23            8      316                  143         2.65    5.9   4.00
# 24           10      353                  128         1.94    5.3   8.00
# 25            2      161                  133         8.87   10.7    NaN
# 26            5      517                  271         4.30    8.2    NaN
# 27            1       79                   15         0.58    3.0    NaN
# 28            3      172                   90         1.96    3.7   0.00
# 29            4      334                  100         1.33    4.5    NaN
# 30            3       90                   52         2.26    3.9    NaN
# 31            9      611                  262         2.65    6.2    NaN
# 32            8      511                  257         2.76    5.5   0.00
# 33            5      555                  213         2.32    6.0    NaN
# 34            2       76                   51         3.40    5.1    NaN
# 35            4      169                  131         2.85    3.7   0.00
# 36            0      266                  113         1.64    3.9   0.00
# 37           20     1422                  526         2.38    6.4   8.33
# 38            1       66                   50         1.61    2.1   2.50
# 39            2       36                   29         1.21    1.5   0.00
# 40            0       85                   48         1.20    2.1    NaN
# 41            1       73                   10         0.42    3.0    NaN
# 42            7      489                  124         1.36    5.4    NaN
# 43            7      720                  221         2.19    7.1    NaN
# 44            4      475                  232         3.52    7.2    NaN
# 45            1      196                  161         2.68    3.3   0.00
# 46           12     1071                  429         3.18    7.9   0.00
# 47            3      488                  202         2.56    6.2   2.00
# 48            4      144                  142         1.87    1.9    NaN
# 49            6      260                  115         2.45    5.5    NaN
# 50            3       73                   90         2.90    2.4    NaN
# 51            1       90                   35         0.90    2.3   0.00
# 52            3      163                  101         1.91    3.1   0.00
# 53           17      748                  397         3.42    6.4    NaN
# 54            9      127                   70         1.32    2.4    NaN
# 55            4      135                   70         1.23    2.4   0.00
# 56           12      928                  393         2.60    6.1   0.00
#
#     zone_attempts  PROSPECT RATING  scramble_rate
# 0               1                2       0.069930
# 1               6                5       0.042553
# 2              26                4       0.084656
# 3               3                3       0.044643
# 4              12                0       0.088832
# 5               5                0       0.027990
# 6              11                0       0.025052
# 7               2                1       0.020638
# 8               5                0       0.094991
# 9              28                1       0.102908
# 10              9                0       0.058524
# 11             17                1       0.064748
# 12              3                0       0.048096
# 13             20                0       0.062370
# 14              8                1       0.086059
# 15             29                1       0.045977
# 16             35                1       0.142857
# 17             19                0       0.116525
# 18              4                1       0.032877
# 19             23                1       0.129870
# 20              3                0       0.090909
# 21              9                0       0.048872
# 22             17                3       0.077088
# 23             23                4       0.027473
# 24             17                1       0.043836
# 25              1                1       0.058824
# 26             17                3       0.117438
# 27              2                1       0.021028
# 28              7                0       0.023404
# 29             29                0       0.049689
# 30              5                1       0.046083
# 31             16                0       0.120729
# 32             29                0       0.086614
# 33             13                5       0.077049
# 34              0                3       0.040000
# 35             14                5       0.040084
# 36             23                4       0.051527
# 37             36                4       0.138824
# 38              1                0       0.016055
# 39              9                0       0.013298
# 40              6                0       0.036058
# 41              7                0       0.020566
# 42             22                0       0.048387
# 43             28                0       0.093541
# 44              6                0       0.106061
# 45              2                0       0.027397
# 46             25                4       0.091954
# 47             23                2       0.043084
# 48             22                0       0.051107
# 49             19                1       0.028078
# 50              6                0       0.027460
# 51             15                0       0.015810
# 52             16                1       0.054893
# 53             28                0       0.066667
# 54              9                0       0.029250
# 55              5                2       0.045198
# 56             22                0       0.098398
#
# [57 rows x 1083 columns]
